# %% [markdown]
# ## Import all libraries：

# %%
from enum import unique
from multiprocessing.connection import wait
from random import choice
from numpy import choose
import object_detection
from object_detection import get_object,detect_img, download_and_resize_image,hub,detector,run_detector
import Spotify
import Translations
from time import sleep
import Azure_api
from Azure_api import get_mood, emotion_detect

# %% [markdown]
# ## Source of the image：

# %%
image_urls = [
    "https://i.huffpost.com/gen/2141038/images/o-SAD-OLDER-PERSON-facebook.jpg"
]

# %%
image_path = download_and_resize_image(image_urls[0], 640, 480)

detect_img(image_path)
# Out:
# Image downloaded to /tmp/tmp0zom_c2h.jpg.
# Found 100 objects.
# Inference time:  0.4346907138824463
# All the results:
#   Human face
#   Man
#   Clothing
#   Human nose
#   Human ear
#   Human hand
#   Human hair
#   Human mouth
#   Human eye
#   Human eye
# Inference time: 0.571171760559082
# =========================Object Detection Finished=======================

# %% [markdown]
# ## Running the Emotion Detection：

# %%
emotion_detect(image_path)
# Out:
# [{'faceId': '4ec33491-1224-42a2-abc2-eb4e8f226df1', 'faceRectangle': {'top': 53, 'left': 107, 'width': 280, 'height': 280}, 'faceAttributes': {'gender': 'male', 'age': 68.0, 'emotion': {'anger': 0.0, 'contempt': 0.004, 'disgust': 0.0, 'fear': 0.0, 'happiness': 0.0, 'neutral': 0.594, 'sadness': 0.401, 'surprise': 0.0}}}]
# 640 -width
# 480 -height

# %%
print("\nThe emotion_result is: ", get_mood())
print("\nThe object_result is: ", get_object())
# Out:
# The emotion_result is:  neutral
#
# The object_result is:  ['Human face', 'Man', 'Clothing', 'Human nose', 'Human ear', 'Human hand', 'Human hair', 'Human mouth', 'Human eye', 'Human eye', 'Human hair', 'Human arm', 'Human hair', 'Human mouth', 'Human hand', 'Clothing', 'Human hair', 'Human hand', 'Human mouth', 'Human arm', 'Human ear', 'Human ear', 'Human eye', 'Human mouth', 'Human arm', 'Human arm', 'Clothing', 'Clothing', 'Window', 'Human hand', 'Human hair', 'Human nose', 'Human ear', 'Window', 'Human hand', 'Human hand', 'Human hair', 'Human hand', 'Human arm', 'Human arm', 'Human hair', 'Human hand', 'Human mouth', 'Human ear', 'Human ear', 'Human arm', 'Human eye', 'Human hand', 'Clothing', 'Clothing', 'Person', 'Human hair', 'Window', 'Human hand', 'Human arm', 'Human hand', 'Clothing', 'Window', 'Clothing', 'Human nose', 'Human nose', 'Human mouth', 'Human head', 'Human nose', 'Human hair', 'Human hand', 'Human eye', 'Human hand', 'Window', 'Window', 'Human hair', 'Clothing', 'Clothing', 'Human hair', 'Human hand', 'Human hand', 'Human nose', 'Human eye', 'Human mouth', 'Human eye', 'Human nose', 'Human arm', 'Human hand', 'Human arm', 'Human eye', 'Human hair', 'Human eye', 'Window', 'Human hand', 'Human head', 'Human eye', 'Human ear', 'Human ear', 'Human hand', 'Human ear', 'Human hair', 'Human nose', 'Window', 'Human ear', 'Human nose', 'Human face', 'Man', 'Clothing', 'Human nose', 'Human ear', 'Human hand', 'Human hair', 'Human mouth', 'Human eye', 'Human eye', 'Human hair', 'Human arm', 'Human hair', 'Human mouth', 'Human hand', 'Clothing', 'Human hair', 'Human hand', 'Human mouth', 'Human arm', 'Human ear', 'Human ear', 'Human eye', 'Human mouth', 'Human arm', 'Human arm', 'Clothing', 'Clothing', 'Window', 'Human hand', 'Human hair', 'Human nose', 'Human ear', 'Window', 'Human hand', 'Human hand', 'Human hair', 'Human hand', 'Human arm', 'Human arm', 'Human hair', 'Human hand', 'Human mouth', 'Human ear', 'Human ear', 'Human arm', 'Human eye', 'Human hand', 'Clothing', 'Clothing', 'Person', 'Human hair', 'Window', 'Human hand', 'Human arm', 'Human hand', 'Clothing', 'Window', 'Clothing', 'Human nose', 'Human nose', 'Human mouth', 'Human head', 'Human nose', 'Human hair', 'Human hand', 'Human eye', 'Human hand', 'Window', 'Window', 'Human hair', 'Clothing', 'Clothing', 'Human hair', 'Human hand', 'Human hand', 'Human nose', 'Human eye', 'Human mouth', 'Human eye', 'Human nose', 'Human arm', 'Human hand', 'Human arm', 'Human eye', 'Human hair', 'Human eye', 'Window', 'Human hand', 'Human head', 'Human eye', 'Human ear', 'Human ear', 'Human hand', 'Human ear', 'Human hair', 'Human nose', 'Window', 'Human ear', 'Human nose', 'Human face', 'Man', 'Clothing', 'Human nose', 'Human ear', 'Human hand', 'Human hair', 'Human mouth', 'Human eye', 'Human eye', 'Human hair', 'Human arm', 'Human hair', 'Human mouth', 'Human hand', 'Clothing', 'Human hair', 'Human hand', 'Human mouth', 'Human arm', 'Human ear', 'Human ear', 'Human eye', 'Human mouth', 'Human arm', 'Human arm', 'Clothing', 'Clothing', 'Window', 'Human hand', 'Human hair', 'Human nose', 'Human ear', 'Window', 'Human hand', 'Human hand', 'Human hair', 'Human hand', 'Human arm', 'Human arm', 'Human hair', 'Human hand', 'Human mouth', 'Human ear', 'Human ear', 'Human arm', 'Human eye', 'Human hand', 'Clothing', 'Clothing', 'Person', 'Human hair', 'Window', 'Human hand', 'Human arm', 'Human hand', 'Clothing', 'Window', 'Clothing', 'Human nose', 'Human nose', 'Human mouth', 'Human head', 'Human nose', 'Human hair', 'Human hand', 'Human eye', 'Human hand', 'Window', 'Window', 'Human hair', 'Clothing', 'Clothing', 'Human hair', 'Human hand', 'Human hand', 'Human nose', 'Human eye', 'Human mouth', 'Human eye', 'Human nose', 'Human arm', 'Human hand', 'Human arm', 'Human eye', 'Human hair', 'Human eye', 'Window', 'Human hand', 'Human head', 'Human eye', 'Human ear', 'Human ear', 'Human hand', 'Human ear', 'Human hair', 'Human nose', 'Window', 'Human ear', 'Human nose', 'Human face', 'Man', 'Clothing', ' ...

# %% [markdown]
# ## Return a playlist:

# %%
obj= list(dict.fromkeys(get_object())) 
unique_songs=Translations.Get_Songs_from_mood(get_mood(),obj)

print('\n Pool of songs:\n')
i=0
for song in unique_songs:
   i+=1
   print(i,'-',song[0],song[1],song[3])
choice =Translations.make_a_choice(unique_songs)
print('\n\n\n','The final choice is:\n', choice[0],choice[1],choice[3])
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /home/umar/Desktop/pro/CCC/CCC/server/Components/TheMain.ipynb Cell 10' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/home/umar/Desktop/pro/CCC/CCC/server/Components/TheMain.ipynb#ch0000009?line=0'>1</a> obj= list(dict.fromkeys(get_object()))
# ----> <a href='vscode-notebook-cell:/home/umar/Desktop/pro/CCC/CCC/server/Components/TheMain.ipynb#ch0000009?line=1'>2</a> unique_songs=Translations.Get_Songs_from_mood(get_mood(),obj)
#
# File ~/Desktop/pro/CCC/CCC/server/Components/Translations.py:201, in Get_Songs_from_mood(mood, obj_in_pic)
#     199 Songs = []
#     200 # each time means 100 songs
# --> 201 Songs.extend(Spotify.get_recommendations(parameters))
#     202 Songs.extend(Spotify.get_recommendations(parameters))
#     203 while not Songs:
#
# File ~/Desktop/pro/CCC/CCC/server/Components/Spotify.py:137, in get_recommendations(parameters)
#     136 def get_recommendations(parameters):
# --> 137     seeds =get_seeds()
#     138     params={"seed_artists": [seeds[2][i][0] for i in range(len(seeds[2]))] , "seed_genres": seeds[0] , "seed_tracks": seeds[1]  , "limit": 100,}
#     139     par_values=parameters.copy()
#
# File ~/Desktop/pro/CCC/CCC/server/Components/Spotify.py:106, in get_seeds()
#     101 def get_seeds():
#     102     # searches for the favourite artists into the liked songs,
#     103     # the 5 favourite songs and the 5 favourite artists are selected to be part of the seed for the recommendation,
#     104     # moreover it uses "Get Available Genre Seeds" in order to get the genres seeds
#     105     seeds=[]
# --> 106     available_genres = get_possible_genres_seeds()
#     107     Genres_seed = select_genres(available_genres)
#     108     liked_songs=get_liked_songs()
#
# File ~/Desktop/pro/CCC/CCC/server/Components/Spotify.py:78, in get_possible_genres_seeds()
#      76 search_url="https://api.spotify.com/v1/recommendations/available-genre-seeds"
#      77 req=requests.get(url=search_url, params=params,headers=header)
# ---> 78 assert req.status_code==200, req.content
#      79 answer=req.json()
#      80 available_genres=answer["genres"]
#
# AssertionError: b'{\n  "error": {\n    "status": 401,\n    "message": "Invalid access token"\n  }\n}'
